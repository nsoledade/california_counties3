# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from src.config import DADOS_LIMPOS
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294117                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343676                  2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float32
#  1   latitude                  17564 non-null  float32
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float32
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float32
#  12  population_per_household  17564 non-null  float32
#  13  bedrooms_per_room         17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %%
coluna_target = ["median_house_value"]

coluna_one_hot_encoder = ["ocean_proximity"]

coluna_ordinal_encoder = ["median_income_cat"]

# %%
colunas_robust_scaler = df.columns.difference(coluna_target + coluna_one_hot_encoder + coluna_ordinal_encoder)

colunas_robust_scaler
# Out:
# Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population', 'population_per_household',
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='object')

# %%
pipeline_robust = Pipeline(steps=[
    ("robust_scaler", RobustScaler()),
    ("poly", PolynomialFeatures(degree=1, include_bias=False))
])

preprocessamento = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder),
        ("one_hot", OneHotEncoder(drop="first"), coluna_one_hot_encoder),
        ("robust_scaler_poly", pipeline_robust, colunas_robust_scaler),
    ],
)

# %%
X = df.drop(columns=coluna_target)
y = df[coluna_target]

# %%
X.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income ocean_proximity  median_income_cat  \
# 0         322         126         8.3252        NEAR BAY                  5
# 1        2401        1138         8.3014        NEAR BAY                  5
# 2        1206         595         2.0804        NEAR BAY                  2
# 3         697         264         2.1250        NEAR BAY                  2
# 4         990         419         1.9911        NEAR BAY                  2
#
#    rooms_per_household  population_per_household  bedrooms_per_room
# 0             6.984127                  2.555556           0.146591
# 1             6.238137                  2.109842           0.155797
# 2             4.294117                  2.026891           0.260274
# 3             4.242424                  2.640152           0.252679
# 4             5.343676                  2.362768           0.203216

# %%
y.head()
# Out:
#    median_house_value
# 0              452600
# 1              358500
# 2              226700
# 3              140000
# 4              158700

# %%
param_grid = {
    "regressor__preprocessor__robust_scaler_poly__poly__degree": [1, 2, 3],
    "regressor__reg__alpha": [1E-2, 5E-2, 0.1, 0.25, 0.5, 1.0],
    "regressor__reg__l1_ratio": [0.1, 0.25, 0.5, 0.75, 0.9],
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=ElasticNet(),
    preprocessor=preprocessamento,
    target_transformer=QuantileTransformer(output_distribution="normal"),
    param_grid=param_grid,
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5,
#                                                    1.0],
#                          'regressor__reg__l1_ratio': [0.1, 0.25, 0.5, 0.75,
#                                                       0.9]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# C:\Users\chico\anaconda3\envs\machine_learning\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.400e+02, tolerance: 1.762e+00
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5,
#                                                    1.0],
#                          'regressor__reg__l1_ratio': [0.1, 0.25, 0.5, 0.75,
#                                                       0.9]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'regressor__preprocessor__robust_scaler_poly__poly__degree': 3,
#  'regressor__reg__alpha': 0.01,
#  'regressor__reg__l1_ratio': 0.1}

# %%
grid_search.best_score_
# Out:
# np.float64(-51309.24060549609)

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out(),
)

coefs
# Out:
#                                                     coeficiente
# one_hot__ocean_proximity_INLAND                       -0.599298
# robust_scaler_poly__longitude                         -0.379630
# robust_scaler_poly__population_per_household          -0.341210
# robust_scaler_poly__latitude                          -0.212728
# robust_scaler_poly__latitude^2                        -0.193112
# ...                                                         ...
# ordinal_encoder__median_income_cat                     0.092097
# robust_scaler_poly__housing_median_age longitude^2     0.108524
# robust_scaler_poly__bedrooms_per_room                  0.129056
# robust_scaler_poly__housing_median_age median_i...     0.179363
# robust_scaler_poly__median_income                      0.716624
#
# [367 rows x 1 columns]

# %%
plot_coeficientes(coefs)

# %%
coefs[coefs["coeficiente"] == 0]
# Out:
#                                                     coeficiente
# robust_scaler_poly__population_per_household to...          0.0
# robust_scaler_poly__population_per_household to...          0.0
# robust_scaler_poly__population_per_household to...          0.0
# robust_scaler_poly__population_per_household ro...         -0.0
# robust_scaler_poly__total_rooms^3                           0.0
# ...                                                         ...
# robust_scaler_poly__population rooms_per_househ...         -0.0
# robust_scaler_poly__longitude total_bedrooms^2             -0.0
# robust_scaler_poly__latitude rooms_per_househol...         -0.0
# robust_scaler_poly__population total_bedrooms^2            -0.0
# robust_scaler_poly__population total_bedrooms t...          0.0
#
# [210 rows x 1 columns]

# %%
coefs[coefs["coeficiente"].between(-0.1, 0.1) & (coefs["coeficiente"] != 0)]
# Out:
#                                                     coeficiente
# robust_scaler_poly__bedrooms_per_room^2 median_...    -0.082642
# robust_scaler_poly__bedrooms_per_room^2 latitude      -0.074915
# robust_scaler_poly__housing_median_age latitude       -0.067265
# robust_scaler_poly__median_income^2                   -0.067248
# robust_scaler_poly__median_income population_pe...    -0.059577
# ...                                                         ...
# robust_scaler_poly__total_bedrooms                     0.074919
# robust_scaler_poly__housing_median_age populati...     0.084581
# robust_scaler_poly__housing_median_age                 0.087323
# robust_scaler_poly__median_income total_bedrooms       0.091397
# ordinal_encoder__median_income_cat                     0.092097
#
# [142 rows x 1 columns]

# %%
plot_coeficientes(coefs[~coefs["coeficiente"].between(-0.1, 0.1)])

# %%
regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": QuantileTransformer(output_distribution="normal"),
    },
    "ElasticNet_grid_search": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": grid_search.best_estimator_.transformer_,
    },
}


resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
# C:\Users\chico\anaconda3\envs\machine_learning\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.250e+01, tolerance: 1.409e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\chico\anaconda3\envs\machine_learning\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.967e+01, tolerance: 1.415e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\chico\anaconda3\envs\machine_learning\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.611e+01, tolerance: 1.423e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\chico\anaconda3\envs\machine_learning\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.951e+02, tolerance: 1.424e+00
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\chico\anaconda3\envs\machine_learning\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.200e+01, tolerance: 1.432e+00
#   model = cd_fast.enet_coordinate_descent(
#                       model  fit_time score_time   test_r2  \
# 0            DummyRegressor  0.002369   0.003633 -0.000081
# 1            DummyRegressor     0.002   0.003004 -0.000146
# 2            DummyRegressor  0.003401   0.002433 -0.001737
# 3            DummyRegressor     0.002   0.005785 -0.000101
# 4            DummyRegressor  0.003002   0.002998 -0.000114
# 5          LinearRegression  0.023342    0.00734  0.682162
# 6          LinearRegression  0.019899   0.008004   0.66999
# 7          LinearRegression  0.023337   0.008599  0.649247
# 8          LinearRegression  0.024512   0.006822  0.669873
# 9          LinearRegression  0.026485   0.008014  0.669023
# 10  LinearRegression_target  0.029862   0.009515  0.692227
# 11  LinearRegression_target  0.028877   0.007442  0.678395
# 12  LinearRegression_target  0.025819   0.008632  0.653858
# 13  LinearRegression_target  0.029728   0.008061  0.683673
# 14  LinearRegression_target  0.029879   0.008659  0.682148
# 15   ElasticNet_grid_search  3.398581   0.018043  0.734329
# 16   ElasticNet_grid_search  3.376264   0.020999  0.713937
# 17   ElasticNet_grid_search  3.237333   0.017546  0.688187
# 18   ElasticNet_grid_search   3.42512   0.019046  0.718015
# 19   ElasticNet_grid_search  3.092953   0.017723  0.715347
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.006002
# 1                 -75787.787194                    -95217.629397     0.005003
# 2                 -76753.598961                    -96253.253947     0.005834
# 3                 -76837.804811                    -95983.885799     0.007784
# 4                 -76617.245449                    -96182.764729        0.006
# 5                 -39855.690996                    -54254.958188     0.030683
# 6                 -40272.565467                    -54695.230283     0.027904
# 7                  -42178.05929                    -56955.988706     0.031936
# 8                 -40806.492497                    -55146.318803     0.031334
# 9                 -40788.496497                     -55331.35106       0.0345
# 10                -37783.926465                    -53388.990153     0.039377
# 11                -38289.737092                    -53994.232222     0.036319
# 12                -40293.079661                    -56580.342274     0.034451
# 13                -38599.788996                    -53981.445978     0.037789
# 14                -38427.549163                    -54223.209439     0.038538
# 15                -34870.535122                    -49603.053128     3.416624
# 16                -35631.989998                    -50923.294697     3.397263
# 17                -37608.702474                    -53701.383083     3.254879
# 18                -35948.117813                      -50967.0104     3.444166
# 19                -35955.662749                    -51313.354408     3.110677

# %%
df_resultados.groupby("model").mean()
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.002554    0.00357 -0.000436
# ElasticNet_grid_search    3.30605   0.018672  0.713963
# LinearRegression         0.023515   0.007756  0.668059
# LinearRegression_target  0.028833   0.008462   0.67806
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# ElasticNet_grid_search                 -36003.001631
# LinearRegression                        -40780.26095
# LinearRegression_target                -38678.816276
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.006125
# ElasticNet_grid_search                     -51301.619143     3.324722
# LinearRegression                           -55276.769408     0.031271
# LinearRegression_target                    -54433.644013     0.037295

# %%
df_resultados.groupby("model").mean().sort_values(by="test_neg_root_mean_squared_error")
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.002554    0.00357 -0.000436
# LinearRegression         0.023515   0.007756  0.668059
# LinearRegression_target  0.028833   0.008462   0.67806
# ElasticNet_grid_search    3.30605   0.018672  0.713963
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# LinearRegression                        -40780.26095
# LinearRegression_target                -38678.816276
# ElasticNet_grid_search                 -36003.001631
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.006125
# LinearRegression                           -55276.769408     0.031271
# LinearRegression_target                    -54433.644013     0.037295
# ElasticNet_grid_search                     -51301.619143     3.324722

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
plot_residuos_estimador(grid_search.best_estimator_, X, y, fracao_amostra=0.1, eng_formatter=True)
