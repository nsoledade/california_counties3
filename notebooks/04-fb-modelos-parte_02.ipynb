# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from src.config import DADOS_LIMPOS
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294117                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343676                  2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float32
#  1   latitude                  17564 non-null  float32
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float32
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float32
#  12  population_per_household  17564 non-null  float32
#  13  bedrooms_per_room         17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %%
coluna_target = ["median_house_value"]

coluna_one_hot_encoder = ["ocean_proximity"]

coluna_ordinal_encoder = ["median_income_cat"]

# %%
preprocessamento = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder),
        ("one_hot", OneHotEncoder(drop="first"), coluna_one_hot_encoder),
    ],
    remainder="passthrough",
)

# %%
X = df.drop(columns=coluna_target)
y = df[coluna_target]

# %%
X.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income ocean_proximity  median_income_cat  \
# 0         322         126         8.3252        NEAR BAY                  5
# 1        2401        1138         8.3014        NEAR BAY                  5
# 2        1206         595         2.0804        NEAR BAY                  2
# 3         697         264         2.1250        NEAR BAY                  2
# 4         990         419         1.9911        NEAR BAY                  2
#
#    rooms_per_household  population_per_household  bedrooms_per_room
# 0             6.984127                  2.555556           0.146591
# 1             6.238137                  2.109842           0.155797
# 2             4.294117                  2.026891           0.260274
# 3             4.242424                  2.640152           0.252679
# 4             5.343676                  2.362768           0.203216

# %%
y.head()
# Out:
#    median_house_value
# 0              452600
# 1              358500
# 2              226700
# 3              140000
# 4              158700

# %%
target_transformer = PowerTransformer()

regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": target_transformer,
    },
}

# %%
resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                       model  fit_time score_time   test_r2  \
# 0            DummyRegressor  0.001722   0.001205 -0.000081
# 1            DummyRegressor  0.000957   0.000993 -0.000146
# 2            DummyRegressor  0.000822   0.000912 -0.001737
# 3            DummyRegressor  0.000775   0.000866 -0.000101
# 4            DummyRegressor  0.000771   0.000848 -0.000114
# 5          LinearRegression  0.021997   0.009782  0.682162
# 6          LinearRegression  0.017612   0.002952   0.66999
# 7          LinearRegression   0.01661   0.002725  0.649247
# 8          LinearRegression  0.008568    0.00654  0.669873
# 9          LinearRegression  0.010877   0.002496  0.669023
# 10  LinearRegression_target  0.022643   0.006382  0.684232
# 11  LinearRegression_target  0.029845   0.007999  0.671042
# 12  LinearRegression_target  0.019549   0.002597  0.646094
# 13  LinearRegression_target  0.035541   0.002569  0.677544
# 14  LinearRegression_target   0.02022   0.002692  0.677014
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.002927
# 1                 -75787.787194                    -95217.629397      0.00195
# 2                 -76753.598961                    -96253.253947     0.001734
# 3                 -76837.804811                    -95983.885799     0.001641
# 4                 -76617.245449                    -96182.764729     0.001619
# 5                 -39855.690921                    -54254.958115     0.031779
# 6                 -40272.565406                    -54695.230224     0.020564
# 7                 -42178.059246                    -56955.988686     0.019335
# 8                 -40806.492452                     -55146.31876     0.015108
# 9                 -40788.496555                    -55331.351171     0.013373
# 10                -38127.990089                     -54078.01827     0.029025
# 11                -38515.387176                    -54607.941381     0.037844
# 12                -40531.127371                    -57211.351363     0.022146
# 13                -38827.012941                    -54501.880328      0.03811
# 14                -38544.774193                    -54659.330513     0.022912

# %%
df_resultados.groupby("model").mean()
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.001009   0.000965 -0.000436
# LinearRegression         0.015133   0.004899  0.668059
# LinearRegression_target   0.02556   0.004448  0.671185
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# LinearRegression                       -40780.260916
# LinearRegression_target                -38909.258354
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.001974
# LinearRegression                           -55276.769391     0.020032
# LinearRegression_target                    -55011.704371     0.030007

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
param_grid = {
    "transformer": [None, PowerTransformer(), QuantileTransformer(output_distribution="normal")]
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=LinearRegression(),
    preprocessor=preprocessamento,
    target_transformer=target_transformer,
    param_grid=param_grid,
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(remainder='passthrough',
#                                                                                                transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity'])])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=PowerTransformer()),
#              n_jobs=-1,
#              param_grid={'transformer': [None, PowerTransformer(),
#                                          QuantileTransformer(output_distribution='normal')]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(remainder='passthrough',
#                                                                                                transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity'])])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=PowerTransformer()),
#              n_jobs=-1,
#              param_grid={'transformer': [None, PowerTransformer(),
#                                          QuantileTransformer(output_distribution='normal')]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'transformer': QuantileTransformer(output_distribution='normal')}

# %%
grid_search.best_score_
# Out:
# -54407.367283789885

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out(),
)

coefs
# Out:
#                                      coeficiente
# one_hot__ocean_proximity_INLAND        -0.453633
# remainder__longitude                   -0.296080
# remainder__latitude                    -0.289261
# remainder__population_per_household    -0.281783
# one_hot__ocean_proximity_NEAR BAY      -0.203366
# one_hot__ocean_proximity_NEAR OCEAN    -0.058445
# remainder__total_bedrooms              -0.000238
# remainder__total_rooms                 -0.000060
# remainder__population                  -0.000037
# remainder__households                   0.000869
# remainder__housing_median_age           0.006738
# ordinal_encoder__median_income_cat      0.033473
# remainder__rooms_per_household          0.119438
# remainder__median_income                0.389982
# remainder__bedrooms_per_room            3.989936

# %%
plot_coeficientes(coefs)

# %%
regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target_power": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": target_transformer,
    },
    "LinearRegression_target_quantile": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": grid_search.best_estimator_.transformer_,
    },
}


resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                                model  fit_time score_time   test_r2  \
# 0                     DummyRegressor  0.001802   0.002317 -0.000081
# 1                     DummyRegressor  0.000978   0.000958 -0.000146
# 2                     DummyRegressor  0.000771   0.000881 -0.001737
# 3                     DummyRegressor   0.00075   0.001051 -0.000101
# 4                     DummyRegressor   0.00076   0.000871 -0.000114
# 5                   LinearRegression  0.009813   0.004522  0.682162
# 6                   LinearRegression  0.014819   0.007445   0.66999
# 7                   LinearRegression   0.01814   0.007842  0.649247
# 8                   LinearRegression   0.01417   0.009952  0.669873
# 9                   LinearRegression  0.025353   0.003438  0.669023
# 10     LinearRegression_target_power  0.016934    0.00538  0.684232
# 11     LinearRegression_target_power  0.043105   0.002942  0.671042
# 12     LinearRegression_target_power  0.023655    0.00259  0.646094
# 13     LinearRegression_target_power   0.03238   0.008241  0.677544
# 14     LinearRegression_target_power  0.017961   0.002656  0.677014
# 15  LinearRegression_target_quantile  0.011958   0.002756  0.691658
# 16  LinearRegression_target_quantile  0.017792   0.003375  0.678565
# 17  LinearRegression_target_quantile  0.018268   0.002915  0.654178
# 18  LinearRegression_target_quantile  0.013389   0.002832  0.683804
# 19  LinearRegression_target_quantile   0.02163   0.002839  0.682494
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.004119
# 1                 -75787.787194                    -95217.629397     0.001936
# 2                 -76753.598961                    -96253.253947     0.001652
# 3                 -76837.804811                    -95983.885799     0.001801
# 4                 -76617.245449                    -96182.764729     0.001631
# 5                 -39855.690921                    -54254.958115     0.014335
# 6                 -40272.565406                    -54695.230224     0.022264
# 7                 -42178.059246                    -56955.988686     0.025982
# 8                 -40806.492452                     -55146.31876     0.024122
# 9                 -40788.496555                    -55331.351171     0.028791
# 10                -38127.990089                     -54078.01827     0.022314
# 11                -38515.387176                    -54607.941381     0.046047
# 12                -40531.127371                    -57211.351363     0.026245
# 13                -38827.012941                    -54501.880328     0.040621
# 14                -38544.774193                    -54659.330513     0.020617
# 15                -37810.072126                    -53438.328323     0.014714
# 16                 -38275.27384                    -53979.963057     0.021167
# 17                -40283.845467                    -56554.185608     0.021183
# 18                 -38591.26928                    -53970.294461     0.016221
# 19                -38401.901107                    -54193.630034     0.024469

# %%
df_resultados.groupby("model").mean()
# Out:
#                                   fit_time score_time   test_r2  \
# model
# DummyRegressor                    0.001012   0.001216 -0.000436
# LinearRegression                  0.016459    0.00664  0.668059
# LinearRegression_target_power     0.026807   0.004362  0.671185
# LinearRegression_target_quantile  0.016608   0.002943   0.67814
#
#                                  test_neg_mean_absolute_error  \
# model
# DummyRegressor                                  -76702.495836
# LinearRegression                                -40780.260916
# LinearRegression_target_power                   -38909.258354
# LinearRegression_target_quantile                -38672.472364
#
#                                  test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                      -95975.447913     0.002228
# LinearRegression                                    -55276.769391     0.023099
# LinearRegression_target_power                       -55011.704371     0.031169
# LinearRegression_target_quantile                    -54427.280297     0.019551

# %%
plot_comparar_metricas_modelos(df_resultados)
