# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from src.config import DADOS_LIMPOS
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294117                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343676                  2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float32
#  1   latitude                  17564 non-null  float32
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float32
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float32
#  12  population_per_household  17564 non-null  float32
#  13  bedrooms_per_room         17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %%
coluna_target = ["median_house_value"]

coluna_one_hot_encoder = ["ocean_proximity"]

coluna_ordinal_encoder = ["median_income_cat"]

# %%
preprocessamento = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder),
        ("one_hot", OneHotEncoder(drop="first"), coluna_one_hot_encoder),
    ],
    remainder="passthrough",
)

# %%
X = df.drop(columns=coluna_target)
y = df[coluna_target]

# %%
X.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income ocean_proximity  median_income_cat  \
# 0         322         126         8.3252        NEAR BAY                  5
# 1        2401        1138         8.3014        NEAR BAY                  5
# 2        1206         595         2.0804        NEAR BAY                  2
# 3         697         264         2.1250        NEAR BAY                  2
# 4         990         419         1.9911        NEAR BAY                  2
#
#    rooms_per_household  population_per_household  bedrooms_per_room
# 0             6.984127                  2.555556           0.146591
# 1             6.238137                  2.109842           0.155797
# 2             4.294117                  2.026891           0.260274
# 3             4.242424                  2.640152           0.252679
# 4             5.343676                  2.362768           0.203216

# %%
y.head()
# Out:
#    median_house_value
# 0              452600
# 1              358500
# 2              226700
# 3              140000
# 4              158700

# %%
target_transformer = PowerTransformer()

regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": target_transformer,
    },
}

# %%
resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                       model  fit_time score_time   test_r2  \
# 0            DummyRegressor  0.004083   0.004006 -0.000081
# 1            DummyRegressor  0.002103   0.002271 -0.000146
# 2            DummyRegressor  0.001997   0.002086 -0.001737
# 3            DummyRegressor  0.002757   0.002044 -0.000101
# 4            DummyRegressor  0.002014    0.00217 -0.000114
# 5          LinearRegression  0.090642   0.009868  0.682162
# 6          LinearRegression   0.01436   0.007591   0.66999
# 7          LinearRegression  0.014937   0.008366  0.649247
# 8          LinearRegression  0.015483   0.008302  0.669873
# 9          LinearRegression  0.014553    0.00748  0.669023
# 10  LinearRegression_target  0.032838   0.007206  0.684232
# 11  LinearRegression_target  0.031151     0.0075  0.671042
# 12  LinearRegression_target   0.02977   0.009189  0.646094
# 13  LinearRegression_target  0.030218   0.008324  0.677544
# 14  LinearRegression_target  0.029523   0.008091  0.677014
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.008089
# 1                 -75787.787194                    -95217.629397     0.004374
# 2                 -76753.598961                    -96253.253947     0.004082
# 3                 -76837.804811                    -95983.885799     0.004802
# 4                 -76617.245449                    -96182.764729     0.004184
# 5                 -39855.690921                    -54254.958115      0.10051
# 6                 -40272.565406                    -54695.230224     0.021951
# 7                 -42178.059246                    -56955.988686     0.023303
# 8                 -40806.492452                     -55146.31876     0.023785
# 9                 -40788.496555                    -55331.351171     0.022033
# 10                -38127.990089                     -54078.01827     0.040044
# 11                -38515.387176                    -54607.941381     0.038651
# 12                -40531.127384                    -57211.351394     0.038959
# 13                -38827.012941                    -54501.880328     0.038543
# 14                -38544.774193                    -54659.330513     0.037614

# %%
df_resultados.groupby("model").mean()
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.002591   0.002516 -0.000436
# LinearRegression         0.029995   0.008321  0.668059
# LinearRegression_target    0.0307   0.008062  0.671185
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# LinearRegression                       -40780.260916
# LinearRegression_target                -38909.258356
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.005106
# LinearRegression                           -55276.769391     0.038316
# LinearRegression_target                    -55011.704377     0.038762

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
param_grid = {
    "transformer": [None, PowerTransformer(), QuantileTransformer(output_distribution="normal")]
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=LinearRegression(),
    preprocessor=preprocessamento,
    target_transformer=target_transformer,
    param_grid=param_grid,
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(remainder='passthrough',
#                                                                                                transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity'])])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=PowerTransformer()),
#              n_jobs=-1,
#              param_grid={'transformer': [None, PowerTransformer(),
#                                          QuantileTransformer(output_distribution='normal')]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(remainder='passthrough',
#                                                                                                transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity'])])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=PowerTransformer()),
#              n_jobs=-1,
#              param_grid={'transformer': [None, PowerTransformer(),
#                                          QuantileTransformer(output_distribution='normal')]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'transformer': QuantileTransformer(output_distribution='normal')}

# %%
grid_search.best_score_
# Out:
# np.float64(-54444.1550082407)

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out(),
)

coefs
# Out:
#                                      coeficiente
# one_hot__ocean_proximity_INLAND        -0.454203
# remainder__longitude                   -0.294322
# remainder__latitude                    -0.287294
# remainder__population_per_household    -0.281307
# one_hot__ocean_proximity_NEAR BAY      -0.203818
# one_hot__ocean_proximity_NEAR OCEAN    -0.056557
# remainder__total_bedrooms              -0.000226
# remainder__total_rooms                 -0.000060
# remainder__population                  -0.000038
# remainder__households                   0.000862
# remainder__housing_median_age           0.006745
# ordinal_encoder__median_income_cat      0.032688
# remainder__rooms_per_household          0.118248
# remainder__median_income                0.390799
# remainder__bedrooms_per_room            3.948818

# %%
plot_coeficientes(coefs)

# %%
regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target_power": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": target_transformer,
    },
    "LinearRegression_target_quantile": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": grid_search.best_estimator_.transformer_,
    },
}


resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                                model  fit_time score_time   test_r2  \
# 0                     DummyRegressor   0.00422      0.005 -0.000081
# 1                     DummyRegressor     0.004      0.004 -0.000146
# 2                     DummyRegressor     0.003      0.005 -0.001737
# 3                     DummyRegressor     0.003      0.005 -0.000101
# 4                     DummyRegressor     0.004   0.004999 -0.000114
# 5                   LinearRegression     0.023    0.01101  0.682162
# 6                   LinearRegression  0.018516   0.009122   0.66999
# 7                   LinearRegression   0.01505   0.007174  0.649247
# 8                   LinearRegression    0.0147   0.008553  0.669873
# 9                   LinearRegression  0.015839    0.00747  0.669023
# 10     LinearRegression_target_power  0.032983    0.00775  0.684232
# 11     LinearRegression_target_power  0.028084   0.009357  0.671042
# 12     LinearRegression_target_power  0.030316   0.008518  0.646094
# 13     LinearRegression_target_power     0.033   0.007372  0.677544
# 14     LinearRegression_target_power   0.02957   0.008177  0.677014
# 15  LinearRegression_target_quantile  0.023261      0.008  0.692268
# 16  LinearRegression_target_quantile  0.022071   0.008495  0.678573
# 17  LinearRegression_target_quantile  0.017196   0.006998  0.654255
# 18  LinearRegression_target_quantile  0.022512   0.008003  0.684294
# 19  LinearRegression_target_quantile  0.021447      0.008  0.682637
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692      0.00922
# 1                 -75787.787194                    -95217.629397        0.008
# 2                 -76753.598961                    -96253.253947        0.008
# 3                 -76837.804811                    -95983.885799        0.008
# 4                 -76617.245449                    -96182.764729     0.008998
# 5                 -39855.690921                    -54254.958115      0.03401
# 6                 -40272.565406                    -54695.230224     0.027638
# 7                 -42178.059246                    -56955.988686     0.022224
# 8                 -40806.492452                     -55146.31876     0.023252
# 9                 -40788.496555                    -55331.351171     0.023309
# 10                -38127.990089                     -54078.01827     0.040733
# 11                -38515.387176                    -54607.941381     0.037441
# 12                -40531.127384                    -57211.351394     0.038834
# 13                -38827.012941                    -54501.880328     0.040371
# 14                -38544.774193                    -54659.330513     0.037746
# 15                -37797.497159                    -53385.504228      0.03126
# 16                 -38284.12297                    -53979.267187     0.030566
# 17                -40273.122926                    -56547.897817     0.024194
# 18                -38592.310445                    -53928.402291     0.030516
# 19                -38405.601935                    -54181.409159     0.029447

# %%
df_resultados.groupby("model").mean()
# Out:
#                                   fit_time score_time   test_r2  \
# model
# DummyRegressor                    0.003644     0.0048 -0.000436
# LinearRegression                  0.017421   0.008666  0.668059
# LinearRegression_target_power     0.030791   0.008235  0.671185
# LinearRegression_target_quantile  0.021297   0.007899  0.678405
#
#                                  test_neg_mean_absolute_error  \
# model
# DummyRegressor                                  -76702.495836
# LinearRegression                                -40780.260916
# LinearRegression_target_power                   -38909.258356
# LinearRegression_target_quantile                -38670.531087
#
#                                  test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                      -95975.447913     0.008444
# LinearRegression                                    -55276.769391     0.026087
# LinearRegression_target_power                       -55011.704377     0.039025
# LinearRegression_target_quantile                    -54404.496137     0.029197

# %%
df_resultados.groupby("model").mean().sort_values(by="test_neg_root_mean_squared_error")
# Out:
#                                   fit_time score_time   test_r2  \
# model
# DummyRegressor                    0.003644     0.0048 -0.000436
# LinearRegression                  0.017421   0.008666  0.668059
# LinearRegression_target_power     0.030791   0.008235  0.671185
# LinearRegression_target_quantile  0.021297   0.007899  0.678405
#
#                                  test_neg_mean_absolute_error  \
# model
# DummyRegressor                                  -76702.495836
# LinearRegression                                -40780.260916
# LinearRegression_target_power                   -38909.258356
# LinearRegression_target_quantile                -38670.531087
#
#                                  test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                      -95975.447913     0.008444
# LinearRegression                                    -55276.769391     0.026087
# LinearRegression_target_power                       -55011.704377     0.039025
# LinearRegression_target_quantile                    -54404.496137     0.029197

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
plot_residuos_estimador(grid_search.best_estimator_, X, y, fracao_amostra=0.1, eng_formatter=True)
